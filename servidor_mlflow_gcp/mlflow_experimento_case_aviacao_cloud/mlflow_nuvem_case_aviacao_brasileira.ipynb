# %% [markdown]
# # Pacotes

# %%
# Bibliotecas padrão e de manipulação de data
import pandas as pd
import numpy as np 
from unidecode import unidecode
import unidecode as uni
from pytz import timezone
import re

pd.set_option('display.max_columns', None)

# Visualização de dados
import seaborn as sns
import matplotlib.pyplot as plt

# Machine Learning - pré-processamento e métricas
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, RepeatedStratifiedKFold, KFold, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, roc_auc_score, recall_score, precision_score, log_loss, roc_curve, average_precision_score, classification_report
from sklearn.metrics import roc_curve, precision_recall_curve
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, precision_recall_curve, auc

# Machine Learning - Modelo de Regressão Logística
import statsmodels.api as sm

# Machine Learning - modelos e otimização
import xgboost as xgb
from xgboost import plot_importance
from xgboost import plot_tree
import sklearn
import shap
from shap import Explainer
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK, space_eval,SparkTrials
from hyperopt.pyll import scope
from skopt import forest_minimize
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline

# Salvamento e carregamento de modelos
import pickle
import os
import mlflow

# Outras bibliotecas

from mlflow.models import infer_signature
from mlflow.models.signature import infer_signature

import warnings

warnings.filterwarnings("ignore")

plt.style.use('ggplot')
print(xgb.__version__)
print(shap.__version__)
print(sklearn.__version__)
#print(hyperopt.__version__)
# Out:
# 2.0.2
# 0.44.0
# 1.2.0

# %% [markdown]
# # Funções

# %%
def tira_acentos(nome):
    """Remove acentos de strings."""
    txt = uni.unidecode(str(nome))
    return txt

def corrigir_nomes(nome):
    """Remove pontos de strings."""
    nome = nome.replace('.', '')
    return nome

## Dummies
def get_one_hot_enc(feature_col: pd.Series, enc: preprocessing.OneHotEncoder, column_name: str) -> pd.DataFrame:
    """
    Aplica codificação one-hot a uma coluna específica de um DataFrame.

    Args:
    feature_col (pd.Series): Coluna do DataFrame para ser codificada.
    enc (preprocessing.OneHotEncoder): Instância do OneHotEncoder treinada.
    column_name (str): Nome da coluna a ser codificada.

    Processo:
    1. Cria um DataFrame com a coluna especificada.
    2. Aplica a transformação one-hot usando o encoder fornecido.
    3. Retorna um DataFrame com as colunas codificadas.

    Returns:
    pd.DataFrame: DataFrame com as colunas resultantes da codificação one-hot.
    """
    unseen_df = pd.DataFrame(feature_col, columns=[column_name])
    encoded_vec = enc.transform(unseen_df).toarray()
    columns = enc.get_feature_names_out([column_name])
    encoded_df = pd.DataFrame(encoded_vec, columns=columns)
    return encoded_df


# Função para salvar um modelo em um arquivo pickle
def save_pickle(model, file_name: str):
    """
    Salva um objeto modelo em um arquivo pickle.

    Args:
    model (any): O modelo a ser salvo.
    file_name (str): Nome do arquivo pickle a ser criado.

    Processo:
    1. Abre o arquivo pickle em modo de escrita binária.
    2. Salva o objeto modelo no arquivo pickle.
    """
    with open(file_name, 'wb') as file:
        pickle.dump(model, file)

# Função para carregar um modelo de um arquivo pickle
def load_pickle(file_name: str) -> any:
    """
    Carrega um objeto a partir de um arquivo pickle.

    Args:
    file_name (str): Nome do arquivo pickle a ser carregado.

    Processo:
    1. Abre o arquivo pickle em modo de leitura binária.
    2. Carrega e retorna o objeto contido no arquivo pickle.

    Returns:
    any: Objeto carregado do arquivo pickle.
    """
    with open(file_name, 'rb') as file:
        return pickle.load(file)

def print_class_distribution(y, label):
    unique, counts = np.unique(y, return_counts=True)
    distribution = dict(zip(unique, counts))
    total = sum(counts)
    print(f'Distribuição de classes {label}:')
    for k, v in distribution.items():
        print(f'Classe {k}: {v/total:.2%}')
    print('--------------------')

def log_class_distribution(y, label):
    unique, counts = np.unique(y, return_counts=True)
    distribution = dict(zip(unique, counts))
    total = sum(counts)
    print(f'Distribuição de classes {label}:')
    for k, v in distribution.items():
        percentage = v / total
        print(f'Classe {k}: {percentage:.2%}')
        # Logar no MLflow
        mlflow.log_metric(f"{label}_classe_{k}_prop", percentage)
    print('--------------------')


# Função para limpar os nomes dos parâmetros
def clean_param_name(name):
    # Substitui vírgulas e remove acentuação e caracteres especiais
    name = re.sub(r'[^\w\s.-]', '', name)
    name = re.sub(r'\s+', '_', name)  # Substitui espaços por sublinhados
    return name

def unified_hyper_tuning(space):
    """
    Realiza o ajuste de hiperparâmetros e treinamento de um modelo XGBoost com logging completo utilizando MLflow.
    
    Args:
        space (dict): Dicionário contendo os hiperparâmetros para o modelo XGBoost.
        
    Returns:
        dict: Dicionário contendo o 'loss' (negativo da média do AUC) e o 'status'.
    """
    mlflow.xgboost.autolog()
    with mlflow.start_run(experiment_id=experiment_id, run_name='XGboost Model Training and Tuning', nested=True):
        #  Configuração do modelo com os parâmetros do espaço
        clf = xgb.XGBClassifier(max_depth = space['max_depth'],
                                  learning_rate = space['learning_rate'],
                                  reg_alpha = space['reg_alpha'],
                                  reg_lambda = space['reg_lambda'],
                                  min_child_weight = space['min_child_weight'],
                                  subsample = space['subsample'],
                                  colsample_bytree = space['colsample_bytree'],
                                  gamma = space['gamma'],
                                  objective = space['objective'],
                                  seed = space['seed'])
        
        # StratifiedKFold para manter a proporção de classes em cada fold
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
        
        # Avaliação usando cross_val_score no conjunto de treinamento
        auc_scores = cross_val_score(clf, X_train, y_train, cv=skf, scoring='roc_auc')
        mean_auc = auc_scores.mean()

        # Logando a média do AUC
        mlflow.log_metric('mean_auc', mean_auc)
        
        model = clf.fit(X_smote_a, y_smote_a)
        
        
        # Teste do modelo
        y_pred = model.predict(X_test)
        y_pred_proba = model.predict_proba(X_test)[:, 1]
    
        # Teste do modelo e log das curvas
        y_pred_proba = model.predict_proba(X_test)[:, 1]
        precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)
        fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    
        # Plotar e salvar a Curva de Precisão-Recall
        plt.figure(figsize=(8, 6))
        plt.plot(recall, precision, marker='.')
        plt.title('Curva de Precisão-Recall')
        plt.xlabel('Recall')
        plt.ylabel('Precisão')
        plt.savefig('precision_recall_curve.png')
        plt.close()
    
        # Plotar e salvar a Curva ROC
        plt.figure(figsize=(8, 6))
        plt.plot(fpr, tpr, linestyle='--')
        plt.title('Curva ROC')
        plt.xlabel('Taxa de Falso Positivo')
        plt.ylabel('Taxa de Verdadeiro Positivo')
        plt.savefig('roc_curve.png')
        plt.close()
    
        # Logar gráficos como artefatos
        mlflow.log_artifact('precision_recall_curve.png')
        mlflow.log_artifact('roc_curve.png')

        # Create a model signature
        signature = infer_signature(X_test, model.predict(X_test))
        model_info = mlflow.xgboost.log_model(model, "modelo_xgboost", signature=signature) 
        
        mlflow.xgboost.log_model(model, "model_xgb", signature=signature)
        model_uri = mlflow.get_artifact_uri("model_xgb")
        
        eval_data = pd.DataFrame(X_test, columns=dt_ax.columns)
        eval_data['atraso30_m3'] = y_test.reset_index(drop=True)
        
        result = mlflow.evaluate(model_uri,
                                 eval_data,
                                 targets="atraso30_m3",
                                 model_type="classifier",
                                 evaluators=["default"])

        # A função de perda é o negativo da média do AUC para otimização
        return {'loss': -mean_auc, 'status': STATUS_OK}

space = {
  'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
  'learning_rate': hp.loguniform('learning_rate', -3, 0),
  'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
  'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
  'gamma': hp.quniform('gamma', 0.5, 1, 0.05),
  'colsample_bytree': hp.quniform('colsample_bytree', 0.5, 1, 0.05),
  'subsample': hp.quniform('subsample', 0.5, 1, 0.05),
  'min_child_weight': hp.quniform('min_child_weight', 1, 6, 1),
  'objective': 'binary:logistic',
  'seed': 123, # Set a seed for deterministic training
}

def clean_column_names(column_names):
    """Cria um dicionário com os nomes das colunas antigos e os tratados para renomeação.

    Args:
        column_names (list of str): Lista com os nomes das colunas originais.

    Returns:
        dict: Dicionário com os nomes antigos como chaves e os tratados como valores.
    """
    name_map = {}
    for name in column_names:
        # Substitui espaços e pontos por underline
        clean_name = re.sub(r'[\s\.]', '_', name)
        
        # Substitui caracteres especiais por vazio
        clean_name = re.sub(r'[^\w<>]', '', clean_name)
        
        # Substitui '>' e '<' por 'maior' e 'menor'
        clean_name = clean_name.replace('>', 'maior').replace('<', 'menor')
        
        # Assegura que não haja múltiplos underlines consecutivos
        clean_name = re.sub(r'_{2,}', '_', clean_name)
        
        # Remove possíveis underlines no início ou fim do nome
        clean_name = clean_name.strip('_')
        
        name_map[name] = clean_name
    return name_map

# %%
# private key to access the storage account 
os.environ['GOOGLE_APPLICATION_CREDENTIALS']='/mlflow_credentials/gcloud-credentials.json' # Specify the gcs authentification file path

# %%
# !pip install google-cloud 
# !pip install google-cloud-storage
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-cloud in c:\users\pedro\appdata\roaming\python\python311\site-packages (0.34.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-cloud-storage in c:\users\pedro\appdata\roaming\python\python311\site-packages (2.15.0)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from google-cloud-storage) (2.28.1)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from google-cloud-storage) (2.17.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from google-cloud-storage) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.6.0 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from google-cloud-storage) (2.7.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from google-cloud-storage) (2.31.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from google-cloud-storage) (1.5.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (1.62.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (4.25.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (4.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2023.11.17)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\pedro\appdata\roaming\python\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage) (0.5.1)

# %%
mlflow.set_tracking_uri('') # Change to Mlflow URI  (loadbalancer ip)
print("MLflow Version:", mlflow.__version__)
print("MLflow Tracking URI:", mlflow.get_tracking_uri())
print("XGBoost version:",xgb.__version__)

# %%
try_to_log_to_remote_server = True
direct_gcs_access = True

# %%
if direct_gcs_access:
    os.environ['GOOGLE_APPLICATION_CREDENTIALS']='C:/Users/pedro/Documents/GitHub/mlflow_server_pedro/mlflow_credentials/gcloud-credentials.json'

# %%
if try_to_log_to_remote_server:
    mlflow.set_tracking_uri('http://')
    mlflow.set_experiment("Case aviação area brasileira")
# Out:
# 2024/05/01 12:09:03 INFO mlflow.tracking.fluent: Experiment with name 'Case aviação area brasileira' does not exist. Creating a new experiment.

# %% [markdown]
# # dataset

# %% [markdown]
# # Definindo um experimento

# %%
# Definindo um experimento
mlflow.set_experiment("Case aviação area brasileira")
# local. Importante direcionar a localização do arquivo de experimento.
# mlflow ui --backend-store-uri file:////mlruns

# %%
# Substitua 'Nome do Experimento' pelo nome que deseja verificar ou criar
experiment_name = "Case aviação area brasileira"
experiment = mlflow.get_experiment_by_name(experiment_name)
experiment_id = experiment.experiment_id

# %%
experiment_id
# Out:
# '1'

# %% [markdown]
# # Tratamento de dados

# %%
# Start an MLflow run context
with mlflow.start_run(experiment_id=experiment_id, run_name='extração e tratamento dos dados', 
                      run_id='a4d5c7afb2d04097bb2253447bf40b7d',
                      description = 'Extração e/ou tratamento de dados',
                      tags = {"Extração": "origem_x", "objetivo": "alimentar o modelo_x", "Versão da etapa": "1.0"}):
    file_path = 'historico_voo_tratados_train.csv'
    df = pd.read_csv(file_path)

# %% [markdown]
# # Treinamento

# %% [markdown]
# ## Pre-processamento

# %% [markdown]
# ### One hot encoding

# %%
with mlflow.start_run(experiment_id=experiment_id, run_name='Pre-processamento',
                      run_id='c8a4ae5791a34914934add55178fba93',
                      nested=True,
                      description = 'Garantir o input correto dos modelos',
                      tags = {"Pre-processamento": "preparação para treinamento", "objetivo": "garantir o input correto dos dados", "Versão da etapa": "1.0"}):
    
    chosen_columns = ['nome_empresas','codigo_tipo_linha','descricao_origem','descricao_destino','pais_origem','pais_destino','continente_origem',
                 'continente_destino','cidade_origem','cidade_destino','uf_origem','uf_destino','mes_partida',
                 'dia_semana_chegada','status_do_voo']
    
    dft = df[chosen_columns].sample(frac=0.3, random_state=13)
    
    # Colunas que precisam passar por one hot encoding
    list_dummies = ['nome_empresas','codigo_tipo_linha','descricao_origem','descricao_destino','pais_origem','pais_destino','continente_origem',
                 'continente_destino','cidade_origem','cidade_destino','uf_origem','uf_destino','mes_partida',
                 'dia_semana_chegada']

    final_data = pd.DataFrame()
    # Logar os parâmetros
    mlflow.log_param("Colunas escolhidas", chosen_columns)
    mlflow.log_param("Index", 'num_cpf')
    mlflow.log_param("Colunas para one-hot encoding", list_dummies)
    
    # Logar métricas
    mlflow.log_metric("Quantidade de colunas", len(chosen_columns))
    mlflow.log_metric("Quantidade de colunas dummies", len(list_dummies))
    mlflow.log_metric("Quantidade de colunas não dummies", len(chosen_columns) - len(list_dummies) - 1) 
    
    ### One hot encoding
    with mlflow.start_run(experiment_id=experiment_id, nested=True, run_name='One hot encoding', #run_id='425440d6597c4186b6d1fe12dc35ff2c',
                      description = 'Transformação das colunas categoricas em númericas',
                      tags = {"One hot encoding": "Transformar categorica em númerica", "objetivo": "garantir o input correto dos dados", "Versão da etapa": "1.0"}):
        for column in list_dummies:
            encoder = preprocessing.OneHotEncoder(handle_unknown='ignore')
            encoder.fit(dft[[column]])
            
            # Logar parâmetros para cada coluna processada
            mlflow.log_param(f"Coluna_{column.lower()}", column.lower())
            
            enc_df = pd.DataFrame(encoder.transform(dft[[column]]).toarray(), 
                                  columns=encoder.get_feature_names_out([column]))
            final_data = pd.concat([final_data, enc_df], axis=1)

        final_data['status_do_voo'] = dft['status_do_voo'].values

        dt_ax = final_data.drop(columns=["status_do_voo"])
        dt_ay = final_data[['status_do_voo']].copy()

        # Transformação da coluna em valores binarios. Pontual = 1 e Atrasado = 0
        label_encoder = LabelEncoder()
        dt_ay_enc = label_encoder.fit_transform(dt_ay)
        dt_ay_df = pd.DataFrame(dt_ay_enc, columns=dt_ay.columns)

        # Suponha que 'df' é o seu DataFrame
        column_names = dt_ax.columns.tolist()
        name_map = clean_column_names(column_names)
        
        # Renomear colunas no DataFrame
        dt_ax.rename(columns=name_map, inplace=True)
        
    ### Normalização / Segmentação  treino e teste / Smote
    with mlflow.start_run(experiment_id=experiment_id, run_name='Normalização e Smote', nested=True, run_id='674eeaa2a0504371b5f1d99ba4c7ad79',
                      description = 'Implementação da etapa de normalização e SMOTE dos dados. Essas etapas são essenciais para evitar overfiting e underfitting',
                      tags = {"Normalização e SMOTE": "Normalização em range de 0 a 1 e criação de dados sinteticos para balencear", "objetivo": "garantir qualidade no correto dos dados", "Versão da etapa": "1.0"}):
        # Normalização dos dados
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(dt_ax)
        X_scaled_df = pd.DataFrame(X_scaled, columns=dt_ax.columns)
    
        # Segmentação em Treino (85%) e Teste (15%)
        X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, dt_ay_df, random_state=13, test_size=0.15)
    
        # Logar distribuição das classes antes do SMOTE
        log_class_distribution(y_test, 'original')
    
        # Aplicar SMOTE
        smote = SMOTE(random_state=13)
        X_smote_a, y_smote_a = smote.fit_resample(X_train, y_train)

        X_test = X_test.reset_index().drop(columns = 'index')
        y_test = y_test.reset_index().drop(columns = 'index')
    
        # Logar distribuição das classes após SMOTE
        log_class_distribution(y_smote_a, 'SMOTE')
# Out:
# Distribuição de classes original:
# Classe 0: 13.62%
# Classe 1: 86.38%
# --------------------
# Distribuição de classes SMOTE:
# Classe 0: 50.00%
# Classe 1: 50.00%
# --------------------

# %% [markdown]
# ## XGBoost

# %% [markdown]
# ### Hipertunnig

# %%
# Etapa de hipertunning
with mlflow.start_run(experiment_id=experiment_id, run_name='Hipertunnig', nested=True,#run_id='a51480d6bb1f41cf99cee7b9d87e7dc0',
                      description = 'Busca pelos melhores parametros. Os modelos testados são armazenados, mesmo que não tenha os melhores parametros.',
                      tags = {"Hipertunnig": "Melhores parametros", "objetivo": "garantir os melhores parametros para o modelo", "Versão da etapa": "1.0"}):
    # Executando a otimização
    trials = Trials()
    best_hyperparams = fmin(fn=unified_hyper_tuning, 
                            space=space, 
                            algo=tpe.suggest, 
                            max_evals=2, 
                            trials=trials)
    
    # Obtendo os melhores hiperparâmetros
    mlflow.log_params(best_hyperparams)
    best_hyperparams = space_eval(space, best_hyperparams)
    print("Melhores hiperparâmetros:", best_hyperparams)
# Out:
#   0%|                                                                            | 0/2 [00:00<?, ?trial/s, best loss=?]
# 2024/05/01 12:17:34 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under gs://mlflow-bucket-teste/mlruns/1/cf4333f2d2f24b88b4e1c8e41d0f7f9f/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
#
# 2024/05/01 12:19:19 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under gs://mlflow-bucket-teste/mlruns/1/cf4333f2d2f24b88b4e1c8e41d0f7f9f/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
#
# 2024/05/01 12:21:03 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under gs://mlflow-bucket-teste/mlruns/1/cf4333f2d2f24b88b4e1c8e41d0f7f9f/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
#
# 2024/05/01 12:22:47 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under gs://mlflow-bucket-teste/mlruns/1/cf4333f2d2f24b88b4e1c8e41d0f7f9f/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
#
# 2024/05/01 12:24:31 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under gs://mlflow-bucket-teste/mlruns/1/cf4333f2d2f24b88b4e1c8e41d0f7f9f/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
#
# 2024/05/01 12:26:27 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under gs://mlflow-bucket-teste/mlruns/1/cf4333f2d2f24b88b4e1c8e41d0f7f9f/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
#
# 2024/05/01 12:29:26 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under gs://mlflow-bucket-teste/mlruns/1/cf4333f2d2f24b88b4e1c8e41d0f7f9f/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
#
# 2024/05/01 12:30:33 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under gs://mlflow-bucket-teste/mlruns/1/cf4333f2d2f24b88b4e1c8e41d0f7f9f/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# Downloading artifacts:   0%|          | 0/9 [00:00<?, ?it/s]
# 2024/05/01 12:31:05 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
#
# 2024/05/01 12:31:05 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
#
# 2024/05/01 12:31:05 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as binary dataset, positive label is 1, negative label is 0.
#
# 2024/05/01 12:31:05 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
#
# 2024/05/01 12:31:09 INFO mlflow.models.evaluation.default_evaluator: Shap explainer PermutationExplainer is used.
#
# PermutationExplainer explainer:   1%|6                                                       | 23/2000 [00:00<?, ?it/s]
#
# PermutationExplainer explainer:   1%|6                                               | 25/2000 [00:10<04:08,  7.94it/s]
#
# PermutationExplainer explainer:   1%|6                                               | 26/2000 [00:10<05:44,  5.73it/s]
#
# PermutationExplainer explainer:   1%|6                                               | 27/2000 [00:10<06:33,  5.01it/s]
#
# PermutationExplainer explainer:   1%|6                                               | 28/2000 [00:11<07:07,  4.62it/s]
#
# PermutationExplainer explainer:   1%|6                                               | 29/2000 [00:11<07:26,  4.41it/s]
#
# PermutationExplainer explainer:   2%|7                                               | 30/2000 [00:11<07:39,  4.28it/s]
#
# PermutationExplainer explainer:   2%|7                                               | 31/2000 [00:12<10:53,  3.01it/s]
#
# PermutationExplainer explainer:   2%|7                                               | 32/2000 [00:12<09:59,  3.28it/s]
#
# PermutationExplainer explainer:   2%|7                                               | 33/2000 [00:12<09:28,  3.46it/s]
#
# PermutationExplainer explainer:   2%|8                                               | 34/2000 [00:12<09:02,  3.63it/s]
#
# PermutationExplainer explainer:   2%|8                                               | 35/2000 [00:13<08:42,  3.76it/s]
#
# PermutationExplainer explainer:   2%|8                                               | 36/2000 [00:13<08:33,  3.82it/s]
#
# PermutationExplainer explainer:   2%|8                                               | 37/2000 [00:13<08:36,  3.80it/s]
#
# PermutationExplainer explainer:   2%|9                                               | 38/2000 [00:13<08:27,  3.87it/s]
#
# PermutationExplainer explainer:   2%|9                                               | 39/2000 [00:14<08:19,  3.93it/s]
#
# PermutationExplainer explainer:   2%|9                                               | 40/2000 [00:14<08:19,  3.92it/s]
#
# PermutationExplainer explainer:   2%|9                                               | 41/2000 [00:14<08:12,  3.98it/s]
#
# PermutationExplainer explainer:   2%|#                                               | 42/2000 [00:14<08:09,  4.00it/s]
#
# PermutationExplainer explainer:   2%|#                                               | 43/2000 [00:15<08:05,  4.03it/s]
#
# PermutationExplainer explainer:   2%|#                                               | 44/2000 [00:15<08:04,  4.04it/s]
#
# PermutationExplainer explainer:   2%|#                                               | 45/2000 [00:15<08:05,  4.03it/s]
#
# PermutationExplainer explainer:   2%|#1                                              | 46/2000 [00:15<08:02,  4.05it/s]
#
# PermutationExplainer explainer:   2%|#1                                              | 47/2000 [00:16<10:59,  2.96it/s]
#
# PermutationExplainer explainer:   2%|#1                                              | 48/2000 [00:16<10:04,  3.23it/s]
#
# PermutationExplainer explainer:   2%|#1                                              | 49/2000 [00:16<09:27,  3.44it/s]
#
# PermutationExplainer explainer:   2%|#2                                              | 50/2000 [00:17<09:07,  3.56it/s]
#
# PermutationExplainer explainer:   3%|#2                                              | 51/2000 [00:17<08:47,  3.69it/s]
#
# PermutationExplainer explainer:   3%|#2                                              | 52/2000 [00:17<08:33,  3.79it/s]
#
# PermutationExplainer explainer:   3%|#2                                              | 53/2000 [00:17<08:26,  3.84it/s]
#
# PermutationExplainer explainer:   3%|#2                                              | 54/2000 [00:18<08:21,  3.88it/s]
#
# PermutationExplainer explainer:   3%|#3                                              | 55/2000 [00:18<08:14,  3.94it/s]
#
# PermutationExplainer explainer:   3%|#3                                              | 56/2000 [00:18<08:13,  3.94it/s]
#
# PermutationExplainer explainer:   3%|#3                                              | 57/2000 [00:18<08:07,  3.99it/s]
#
# PermutationExplainer explainer:   3%|#3                                              | 58/2000 [00:19<08:03,  4.02it/s]
#
# PermutationExplainer explainer:   3%|#4                                              | 59/2000 [00:19<08:04,  4.01it/s]
#
# PermutationExplainer explainer:   3%|#4                                              | 60/2000 [00:19<08:05,  4.00it/s]
#
# PermutationExplainer explainer:   3%|#4                                              | 61/2000 [00:19<08:00,  4.04it/s]
#
# PermutationExplainer explainer:   3%|#4                                              | 62/2000 [00:20<08:03,  4.00it/s]
#
# PermutationExplainer explainer:   3%|#5                                              | 63/2000 [00:20<11:04,  2.92it/s]
#
# PermutationExplainer explainer:   3%|#5                                              | 64/2000 [00:21<10:09,  3.18it/s]
#
# PermutationExplainer explainer:   3%|#5                                              | 65/2000 [00:21<09:29,  3.40it/s]
#
# PermutationExplainer explainer:   3%|#5                                              | 66/2000 [00:21<09:05,  3.55it/s]
#
# PermutationExplainer explainer:   3%|#6                                              | 67/2000 [00:21<08:48,  3.66it/s]
#
# PermutationExplainer explainer:   3%|#6                                              | 68/2000 [00:22<08:32,  3.77it/s]
#
# PermutationExplainer explainer:   3%|#6                                              | 69/2000 [00:22<08:23,  3.84it/s]
#
# PermutationExplainer explainer:   4%|#6                                              | 70/2000 [00:22<08:16,  3.88it/s]
#
# PermutationExplainer explainer:   4%|#7                                              | 71/2000 [00:22<08:07,  3.96it/s]
#
# PermutationExplainer explainer:   4%|#7                                              | 72/2000 [00:23<08:10,  3.93it/s]
#
# PermutationExplainer explainer:   4%|#7                                              | 73/2000 [00:23<08:27,  3.80it/s]
#
# PermutationExplainer explainer:   4%|#7                                              | 74/2000 [00:23<08:13,  3.90it/s]
#
# PermutationExplainer explainer:   4%|#8                                              | 75/2000 [00:23<08:09,  3.94it/s]
#
# PermutationExplainer explainer:   4%|#8                                              | 76/2000 [00:24<08:07,  3.94it/s]
#
# PermutationExplainer explainer:   4%|#8                                              | 77/2000 [00:24<08:08,  3.93it/s]
#
# PermutationExplainer explainer:   4%|#8                                              | 78/2000 [00:24<08:05,  3.96it/s]
#
# PermutationExplainer explainer:   4%|#8                                              | 79/2000 [00:25<11:08,  2.87it/s]
#
# PermutationExplainer explainer:   4%|#9                                              | 80/2000 [00:25<10:14,  3.13it/s]
#
# PermutationExplainer explainer:   4%|#9                                              | 81/2000 [00:25<09:43,  3.29it/s]
#
# PermutationExplainer explainer:   4%|#9                                              | 82/2000 [00:25<09:17,  3.44it/s]
#
# PermutationExplainer explainer:   4%|#9                                              | 83/2000 [00:26<09:04,  3.52it/s]
#
# PermutationExplainer explainer:   4%|##                                              | 84/2000 [00:26<09:11,  3.47it/s]
#
# PermutationExplainer explainer:   4%|##                                              | 85/2000 [00:26<08:51,  3.60it/s]
#
# PermutationExplainer explainer:   4%|##                                              | 86/2000 [00:27<08:52,  3.60it/s]
#
# PermutationExplainer explainer:   4%|##                                              | 87/2000 [00:27<08:37,  3.70it/s]
#
# PermutationExplainer explainer:   4%|##1                                             | 88/2000 [00:27<08:31,  3.74it/s]
#
# PermutationExplainer explainer:   4%|##1                                             | 89/2000 [00:27<08:16,  3.85it/s]
#
# PermutationExplainer explainer:   4%|##1                                             | 90/2000 [00:28<08:10,  3.89it/s]
#
# PermutationExplainer explainer:   5%|##1                                             | 91/2000 [00:28<08:15,  3.85it/s]
#
# PermutationExplainer explainer:   5%|##2                                             | 92/2000 [00:28<08:12,  3.88it/s]
#
# PermutationExplainer explainer:   5%|##2                                             | 93/2000 [00:28<08:04,  3.94it/s]
#
# PermutationExplainer explainer:   5%|##2                                             | 94/2000 [00:29<08:02,  3.95it/s]
#
# PermutationExplainer explainer:   5%|##2                                             | 95/2000 [00:29<08:00,  3.97it/s]
#
# PermutationExplainer explainer:   5%|##3                                             | 96/2000 [00:29<10:54,  2.91it/s]
#
# PermutationExplainer explainer:   5%|##3                                             | 97/2000 [00:30<09:56,  3.19it/s]
#
# PermutationExplainer explainer:   5%|##3                                             | 98/2000 [00:30<09:22,  3.38it/s]
#
# PermutationExplainer explainer:   5%|##3                                             | 99/2000 [00:30<08:52,  3.57it/s]
#
# PermutationExplainer explainer:   5%|##3                                            | 100/2000 [00:30<08:32,  3.71it/s]
#
# PermutationExplainer explainer:   5%|##3                                            | 101/2000 [00:31<08:18,  3.81it/s]
#
# PermutationExplainer explainer:   5%|##3                                            | 102/2000 [00:31<08:08,  3.89it/s]
#
# PermutationExplainer explainer:   5%|##4                                            | 103/2000 [00:31<08:01,  3.94it/s]
#
# PermutationExplainer explainer:   5%|##4                                            | 104/2000 [00:31<07:58,  3.97it/s]
#
# PermutationExplainer explainer:   5%|##4                                            | 105/2000 [00:32<07:53,  4.00it/s]
#
# PermutationExplainer explainer:   5%|##4                                            | 106/2000 [00:32<07:52,  4.01it/s]
#
# PermutationExplainer explainer:   5%|##5                                            | 107/2000 [00:32<07:49,  4.03it/s]
#
# PermutationExplainer explainer:   5%|##5                                            | 108/2000 [00:32<08:07,  3.88it/s]
#
# PermutationExplainer explainer:   5%|##5                                            | 109/2000 [00:33<08:01,  3.93it/s]
#
# PermutationExplainer explainer:   6%|##5                                            | 110/2000 [00:33<07:57,  3.96it/s]
#
# PermutationExplainer explainer:   6%|##6                                            | 111/2000 [00:33<10:47,  2.92it/s]
#
# PermutationExplainer explainer:   6%|##6                                            | 112/2000 [00:34<09:52,  3.18it/s]
#
# PermutationExplainer explainer:   6%|##6                                            | 113/2000 [00:34<09:19,  3.37it/s]
#
# PermutationExplainer explainer:   6%|##6                                            | 114/2000 [00:34<08:50,  3.55it/s]
#
# PermutationExplainer explainer:   6%|##7                                            | 115/2000 [00:34<08:32,  3.68it/s]
#
# PermutationExplainer explainer:   6%|##7                                            | 116/2000 [00:35<08:20,  3.77it/s]
#
# PermutationExplainer explainer:   6%|##7                                            | 117/2000 [00:35<08:10,  3.84it/s]
#
# PermutationExplainer explainer:   6%|##7                                            | 118/2000 [00:35<08:05,  3.88it/s]
#
# PermutationExplainer explainer:   6%|##7                                            | 119/2000 [00:35<08:01,  3.91it/s]
#
# PermutationExplainer explainer:   6%|##8                                            | 120/2000 [00:36<07:55,  3.95it/s]
#
# PermutationExplainer explainer:   6%|##8                                            | 121/2000 [00:36<07:55,  3.95it/s]
#
# PermutationExplainer explainer:   6%|##8                                            | 122/2000 [00:36<07:56,  3.94it/s]
#
# PermutationExplainer explainer:   6%|##8                                            | 123/2000 [00:36<07:58,  3.92it/s]
#
# PermutationExplainer explainer:   6%|##9                                            | 124/2000 [00:37<08:04,  3.87it/s]
#
# PermutationExplainer explainer:   6%|##9                                            | 125/2000 [00:37<08:04,  3.87it/s]
#
# PermutationExplainer explainer:   6%|##9                                            | 126/2000 [00:37<07:56,  3.93it/s]
#
# PermutationExplainer explainer:   6%|##9                                            | 127/2000 [00:38<10:50,  2.88it/s]
#
# PermutationExplainer explainer:   6%|###                                            | 128/2000 [00:38<10:00,  3.12it/s]
#
# PermutationExplainer explainer:   6%|###                                            | 129/2000 [00:38<09:18,  3.35it/s]
#
# PermutationExplainer explainer:   6%|###                                            | 130/2000 [00:38<08:54,  3.50it/s]
#
# PermutationExplainer explainer:   7%|###                                            | 131/2000 [00:39<08:32,  3.65it/s]
#
# PermutationExplainer explainer:   7%|###1                                           | 132/2000 [00:39<08:20,  3.73it/s]
#
# PermutationExplainer explainer:   7%|###1                                           | 133/2000 [00:39<08:12,  3.79it/s]
#
# PermutationExplainer explainer:   7%|###1                                           | 134/2000 [00:39<08:10,  3.80it/s]
#
# PermutationExplainer explainer:   7%|###1                                           | 135/2000 [00:40<07:59,  3.89it/s]
#
# PermutationExplainer explainer:   7%|###1                                           | 136/2000 [00:40<07:54,  3.93it/s]
#
# PermutationExplainer explainer:   7%|###2                                           | 137/2000 [00:40<07:59,  3.89it/s]
#
# PermutationExplainer explainer:   7%|###2                                           | 138/2000 [00:40<07:52,  3.94it/s]
#
# PermutationExplainer explainer:   7%|###2                                           | 139/2000 [00:41<07:50,  3.96it/s]
#
# PermutationExplainer explainer:   7%|###2                                           | 140/2000 [00:41<07:52,  3.94it/s]
#
# PermutationExplainer explainer:   7%|###3                                           | 141/2000 [00:41<07:47,  3.98it/s]
#
# PermutationExplainer explainer:   7%|###3                                           | 142/2000 [00:42<07:55,  3.91it/s]
#
# PermutationExplainer explainer:   7%|###3                                           | 143/2000 [00:42<10:44,  2.88it/s]
#
# PermutationExplainer explainer:   7%|###3                                           | 144/2000 [00:42<09:53,  3.13it/s]
#
# PermutationExplainer explainer:   7%|###4                                           | 145/2000 [00:43<09:09,  3.38it/s]
#
# PermutationExplainer explainer:   7%|###4                                           | 146/2000 [00:43<08:44,  3.54it/s]
#
# PermutationExplainer explainer:   7%|###4                                           | 147/2000 [00:43<08:27,  3.65it/s]
#
# PermutationExplainer explainer:   7%|###4                                           | 148/2000 [00:43<08:11,  3.77it/s]
#
# PermutationExplainer explainer:   7%|###5                                           | 149/2000 [00:44<08:07,  3.80it/s]
#
# PermutationExplainer explainer:   8%|###5                                           | 150/2000 [00:44<08:00,  3.85it/s]
#
# PermutationExplainer explainer:   8%|###5                                           | 151/2000 [00:44<07:50,  3.93it/s]
#
# PermutationExplainer explainer:   8%|###5                                           | 152/2000 [00:44<07:49,  3.94it/s]
#
# PermutationExplainer explainer:   8%|###5                                           | 153/2000 [00:45<07:43,  3.99it/s]
#
# PermutationExplainer explainer:   8%|###6                                           | 154/2000 [00:45<07:45,  3.96it/s]
#
# PermutationExplainer explainer:   8%|###6                                           | 155/2000 [00:45<07:42,  3.99it/s]
#
# PermutationExplainer explainer:   8%|###6                                           | 156/2000 [00:45<07:43,  3.98it/s]
#
# PermutationExplainer explainer:   8%|###6                                           | 157/2000 [00:46<07:37,  4.02it/s]
#
# PermutationExplainer explainer:   8%|###7                                           | 158/2000 [00:46<07:33,  4.06it/s]
#
# PermutationExplainer explainer:   8%|###7                                           | 159/2000 [00:46<10:24,  2.95it/s]
#
# PermutationExplainer explainer:   8%|###7                                           | 160/2000 [00:47<09:31,  3.22it/s]
#
# PermutationExplainer explainer:   8%|###7                                           | 161/2000 [00:47<08:56,  3.43it/s]
#
# PermutationExplainer explainer:   8%|###8                                           | 162/2000 [00:47<08:32,  3.58it/s]
#
# PermutationExplainer explainer:   8%|###8                                           | 163/2000 [00:47<08:14,  3.72it/s]
#
# PermutationExplainer explainer:   8%|###8                                           | 164/2000 [00:48<08:03,  3.80it/s]
#
# PermutationExplainer explainer:   8%|###8                                           | 165/2000 [00:48<08:01,  3.81it/s]
#
# PermutationExplainer explainer:   8%|###9                                           | 166/2000 [00:48<07:53,  3.87it/s]
#
# PermutationExplainer explainer:   8%|###9                                           | 167/2000 [00:48<07:47,  3.92it/s]
#
# PermutationExplainer explainer:   8%|###9                                           | 168/2000 [00:49<07:42,  3.96it/s]
#
# PermutationExplainer explainer:   8%|###9                                           | 169/2000 [00:49<07:41,  3.97it/s]
#
# PermutationExplainer explainer:   8%|###9                                           | 170/2000 [00:49<07:40,  3.98it/s]
#
# PermutationExplainer explainer:   9%|####                                           | 171/2000 [00:49<07:38,  3.99it/s]
#
# PermutationExplainer explainer:   9%|####                                           | 172/2000 [00:50<07:40,  3.97it/s]
#
# PermutationExplainer explainer:   9%|####                                           | 173/2000 [00:50<07:42,  3.95it/s]
#
# PermutationExplainer explainer:   9%|####                                           | 174/2000 [00:50<07:38,  3.99it/s]
#
# PermutationExplainer explainer:   9%|####1                                          | 175/2000 [00:51<10:16,  2.96it/s]
#
# PermutationExplainer explainer:   9%|####1                                          | 176/2000 [00:51<09:28,  3.21it/s]
#
# PermutationExplainer explainer:   9%|####1                                          | 177/2000 [00:51<09:13,  3.29it/s]
#
# PermutationExplainer explainer:   9%|####1                                          | 178/2000 [00:51<08:49,  3.44it/s]
#
# PermutationExplainer explainer:   9%|####2                                          | 179/2000 [00:52<08:26,  3.59it/s]
#
# PermutationExplainer explainer:   9%|####2                                          | 180/2000 [00:52<08:11,  3.70it/s]
#
# PermutationExplainer explainer:   9%|####2                                          | 181/2000 [00:52<07:58,  3.80it/s]
#
# PermutationExplainer explainer:   9%|####2                                          | 182/2000 [00:52<07:50,  3.86it/s]
#
# PermutationExplainer explainer:   9%|####3                                          | 183/2000 [00:53<07:47,  3.89it/s]
#
# PermutationExplainer explainer:   9%|####3                                          | 184/2000 [00:53<07:46,  3.89it/s]
#
# PermutationExplainer explainer:   9%|####3                                          | 185/2000 [00:53<07:39,  3.95it/s]
#
# PermutationExplainer explainer:   9%|####3                                          | 186/2000 [00:53<07:39,  3.95it/s]
#
# PermutationExplainer explainer:   9%|####3                                          | 187/2000 [00:54<07:37,  3.97it/s]
#
# PermutationExplainer explainer:   9%|####4                                          | 188/2000 [00:54<07:33,  3.99it/s]
#
# PermutationExplainer explainer:   9%|####4                                          | 189/2000 [00:54<07:36,  3.97it/s]
#
# PermutationExplainer explainer:  10%|####4                                          | 190/2000 [00:54<07:33,  4.00it/s]
#
# PermutationExplainer explainer:  10%|####4                                          | 191/2000 [00:55<10:08,  2.97it/s]
#
# PermutationExplainer explainer:  10%|####5                                          | 192/2000 [00:55<09:17,  3.24it/s]
#
# PermutationExplainer explainer:  10%|####5                                          | 193/2000 [00:55<08:43,  3.45it/s]
#
# PermutationExplainer explainer:  10%|####5                                          | 194/2000 [00:56<08:25,  3.58it/s]
#
# PermutationExplainer explainer:  10%|####5                                          | 195/2000 [00:56<08:12,  3.66it/s]
#
# PermutationExplainer explainer:  10%|####6                                          | 196/2000 [00:56<07:53,  3.81it/s]
#
# PermutationExplainer explainer:  10%|####6                                          | 197/2000 [00:56<07:50,  3.83it/s]
#
# PermutationExplainer explainer:  10%|####6                                          | 198/2000 [00:57<07:40,  3.91it/s]
#
# PermutationExplainer explainer:  10%|####6                                          | 199/2000 [00:57<07:34,  3.96it/s]
#
# PermutationExplainer explainer:  10%|####7                                          | 200/2000 [00:57<07:36,  3.95it/s]
#
# PermutationExplainer explainer:  10%|####7                                          | 201/2000 [00:57<07:34,  3.96it/s]
#
# PermutationExplainer explainer:  10%|####7                                          | 202/2000 [00:58<07:34,  3.96it/s]
#
# PermutationExplainer explainer:  10%|####7                                          | 203/2000 [00:58<07:31,  3.98it/s]
#
# PermutationExplainer explainer:  10%|####7                                          | 204/2000 [00:58<07:28,  4.00it/s]
#
# PermutationExplainer explainer:  10%|####8                                          | 205/2000 [00:58<07:26,  4.02it/s]
#
# PermutationExplainer explainer:  10%|####8                                          | 206/2000 [00:59<10:05,  2.96it/s]
#
# PermutationExplainer explainer:  10%|####8                                          | 207/2000 [00:59<09:20,  3.20it/s]
#
# PermutationExplainer explainer:  10%|####8                                          | 208/2000 [01:00<08:50,  3.38it/s]
#
# PermutationExplainer explainer:  10%|####9                                          | 209/2000 [01:00<08:19,  3.58it/s]
#
# PermutationExplainer explainer:  10%|####9                                          | 210/2000 [01:00<08:19,  3.58it/s]
#
# PermutationExplainer explainer:  11%|####9                                          | 211/2000 [01:00<08:00,  3.72it/s]
#
# PermutationExplainer explainer:  11%|####9                                          | 212/2000 [01:01<07:51,  3.80it/s]
#
# PermutationExplainer explainer:  11%|#####                                          | 213/2000 [01:01<07:45,  3.84it/s]
#
# PermutationExplainer explainer:  11%|#####                                          | 214/2000 [01:01<07:39,  3.89it/s]
#
# PermutationExplainer explainer:  11%|#####                                          | 215/2000 [01:01<07:32,  3.95it/s]
#
# PermutationExplainer explainer:  11%|#####                                          | 216/2000 [01:02<07:28,  3.98it/s]
#
# PermutationExplainer explainer:  11%|#####                                          | 217/2000 [01:02<07:29,  3.97it/s]
#
# PermutationExplainer explainer:  11%|#####1                                         | 218/2000 [01:02<07:26,  3.99it/s]
#
# PermutationExplainer explainer:  11%|#####1                                         | 219/2000 [01:02<07:28,  3.97it/s]
#
# PermutationExplainer explainer:  11%|#####1                                         | 220/2000 [01:03<07:26,  3.99it/s]
#
# PermutationExplainer explainer:  11%|#####1                                         | 221/2000 [01:03<07:23,  4.01it/s]
#
# PermutationExplainer explainer:  11%|#####2                                         | 222/2000 [01:03<10:05,  2.94it/s]
#
# PermutationExplainer explainer:  11%|#####2                                         | 223/2000 [01:04<09:17,  3.19it/s]
#
# PermutationExplainer explainer:  11%|#####2                                         | 224/2000 [01:04<08:41,  3.40it/s]
#
# PermutationExplainer explainer:  11%|#####2                                         | 225/2000 [01:04<08:16,  3.57it/s]
#
# PermutationExplainer explainer:  11%|#####3                                         | 226/2000 [01:04<07:59,  3.70it/s]
#
# PermutationExplainer explainer:  11%|#####3                                         | 227/2000 [01:05<07:50,  3.77it/s]
#
# PermutationExplainer explainer:  11%|#####3                                         | 228/2000 [01:05<07:43,  3.83it/s]
#
# PermutationExplainer explainer:  11%|#####3                                         | 229/2000 [01:05<07:35,  3.89it/s]
#
# PermutationExplainer explainer:  12%|#####4                                         | 230/2000 [01:05<07:30,  3.93it/s]
#
# PermutationExplainer explainer:  12%|#####4                                         | 231/2000 [01:06<07:28,  3.95it/s]
#
# PermutationExplainer explainer:  12%|#####4                                         | 232/2000 [01:06<07:23,  3.99it/s]
#
# PermutationExplainer explainer:  12%|#####4                                         | 233/2000 [01:06<07:19,  4.02it/s]
#
# PermutationExplainer explainer:  12%|#####4                                         | 234/2000 [01:06<07:21,  4.00it/s]
#
# PermutationExplainer explainer:  12%|#####5                                         | 235/2000 [01:07<07:19,  4.01it/s]
#
# PermutationExplainer explainer:  12%|#####5                                         | 236/2000 [01:07<07:19,  4.02it/s]
#
# PermutationExplainer explainer:  12%|#####5                                         | 237/2000 [01:07<07:25,  3.95it/s]
#
# PermutationExplainer explainer:  12%|#####5                                         | 238/2000 [01:08<10:03,  2.92it/s]
#
# PermutationExplainer explainer:  12%|#####6                                         | 239/2000 [01:08<09:13,  3.18it/s]
#
# PermutationExplainer explainer:  12%|#####6                                         | 240/2000 [01:08<08:35,  3.41it/s]
#
# PermutationExplainer explainer:  12%|#####6                                         | 241/2000 [01:08<08:15,  3.55it/s]
#
# PermutationExplainer explainer:  12%|#####6                                         | 242/2000 [01:09<07:58,  3.67it/s]
#
# PermutationExplainer explainer:  12%|#####7                                         | 243/2000 [01:09<08:03,  3.64it/s]
#
# PermutationExplainer explainer:  12%|#####7                                         | 244/2000 [01:09<07:50,  3.73it/s]
#
# PermutationExplainer explainer:  12%|#####7                                         | 245/2000 [01:09<07:37,  3.83it/s]
#
# PermutationExplainer explainer:  12%|#####7                                         | 246/2000 [01:10<07:31,  3.89it/s]
#
# PermutationExplainer explainer:  12%|#####8                                         | 247/2000 [01:10<07:27,  3.92it/s]
#
# PermutationExplainer explainer:  12%|#####8                                         | 248/2000 [01:10<07:22,  3.96it/s]
#
# PermutationExplainer explainer:  12%|#####8                                         | 249/2000 [01:10<07:15,  4.02it/s]
#
# PermutationExplainer explainer:  12%|#####8                                         | 250/2000 [01:11<07:15,  4.02it/s]
#
# PermutationExplainer explainer:  13%|#####8                                         | 251/2000 [01:11<07:12,  4.04it/s]
#
# PermutationExplainer explainer:  13%|#####9                                         | 252/2000 [01:11<07:12,  4.04it/s]
#
# PermutationExplainer explainer:  13%|#####9                                         | 253/2000 [01:11<07:13,  4.03it/s]
#
# PermutationExplainer explainer:  13%|#####9                                         | 254/2000 [01:12<07:09,  4.06it/s]
#
# PermutationExplainer explainer:  13%|#####9                                         | 255/2000 [01:12<09:48,  2.97it/s]
#
# PermutationExplainer explainer:  13%|######                                         | 256/2000 [01:12<09:02,  3.22it/s]
#
# PermutationExplainer explainer:  13%|######                                         | 257/2000 [01:13<08:29,  3.42it/s]
#
# PermutationExplainer explainer:  13%|######                                         | 258/2000 [01:13<08:08,  3.57it/s]
#
# PermutationExplainer explainer:  13%|######                                         | 259/2000 [01:13<07:49,  3.71it/s]
#
# PermutationExplainer explainer:  13%|######1                                        | 260/2000 [01:13<07:34,  3.82it/s]
#
# PermutationExplainer explainer:  13%|######1                                        | 261/2000 [01:14<07:28,  3.88it/s]
#
# PermutationExplainer explainer:  13%|######1                                        | 262/2000 [01:14<07:22,  3.93it/s]
#
# PermutationExplainer explainer:  13%|######1                                        | 263/2000 [01:14<07:19,  3.96it/s]
#
# PermutationExplainer explainer:  13%|######2                                        | 264/2000 [01:14<07:21,  3.93it/s]
#
# PermutationExplainer explainer:  13%|######2                                        | 265/2000 [01:15<07:15,  3.98it/s]
#
# PermutationExplainer explainer:  13%|######2                                        | 266/2000 [01:15<07:13,  4.00it/s]
#
# PermutationExplainer explainer:  13%|######2                                        | 267/2000 [01:15<07:10,  4.02it/s]
#
# PermutationExplainer explainer:  13%|######2                                        | 268/2000 [01:15<07:06,  4.06it/s]
#
# PermutationExplainer explainer:  13%|######3                                        | 269/2000 [01:16<07:07,  4.05it/s]
#
# PermutationExplainer explainer:  14%|######3                                        | 270/2000 [01:16<09:49,  2.93it/s]
#
# PermutationExplainer explainer:  14%|######3                                        | 271/2000 [01:16<08:58,  3.21it/s]
#
# PermutationExplainer explainer:  14%|######3                                        | 272/2000 [01:17<08:27,  3.40it/s]
#
# PermutationExplainer explainer:  14%|######4                                        | 273/2000 [01:17<08:04,  3.56it/s]
#
# PermutationExplainer explainer:  14%|######4                                        | 274/2000 [01:17<07:48,  3.68it/s]
#
# PermutationExplainer explainer:  14%|######4                                        | 275/2000 [01:17<07:56,  3.62it/s]
#
# PermutationExplainer explainer:  14%|######4                                        | 276/2000 [01:18<07:42,  3.73it/s]
#
# PermutationExplainer explainer:  14%|######5                                        | 277/2000 [01:18<07:29,  3.84it/s]
#
# PermutationExplainer explainer:  14%|######5                                        | 278/2000 [01:18<07:25,  3.86it/s]
#
# PermutationExplainer explainer:  14%|######5                                        | 279/2000 [01:18<07:19,  3.91it/s]
#
# PermutationExplainer explainer:  14%|######5                                        | 280/2000 [01:19<07:15,  3.95it/s]
#
# PermutationExplainer explainer:  14%|######6                                        | 281/2000 [01:19<07:22,  3.88it/s]
#
# PermutationExplainer explainer:  14%|######6                                        | 282/2000 [01:19<07:16,  3.94it/s]
#
# PermutationExplainer explainer:  14%|######6                                        | 283/2000 [01:20<07:17,  3.92it/s]
#
# PermutationExplainer explainer:  14%|######6                                        | 284/2000 [01:20<07:18,  3.91it/s]
#
# PermutationExplainer explainer:  14%|######6                                        | 285/2000 [01:20<07:18,  3.91it/s]
#
# PermutationExplainer explainer:  14%|######7                                        | 286/2000 [01:21<09:56,  2.87it/s]
#
# PermutationExplainer explainer:  14%|######7                                        | 287/2000 [01:21<09:01,  3.16it/s]
#
# PermutationExplainer explainer:  14%|######7                                        | 288/2000 [01:21<08:30,  3.35it/s]
#
# PermutationExplainer explainer:  14%|######7                                        | 289/2000 [01:21<08:04,  3.53it/s]
#
# PermutationExplainer explainer:  14%|######8                                        | 290/2000 [01:22<07:46,  3.66it/s]
#
# PermutationExplainer explainer:  15%|######8                                        | 291/2000 [01:22<07:34,  3.76it/s]
#
# PermutationExplainer explainer:  15%|######8                                        | 292/2000 [01:22<07:27,  3.82it/s]
#
# PermutationExplainer explainer:  15%|######8                                        | 293/2000 [01:22<07:20,  3.88it/s]
#
# PermutationExplainer explainer:  15%|######9                                        | 294/2000 [01:23<07:15,  3.91it/s]
#
# PermutationExplainer explainer:  15%|######9                                        | 295/2000 [01:23<07:13,  3.93it/s]
#
# PermutationExplainer explainer:  15%|######9                                        | 296/2000 [01:23<07:09,  3.97it/s]
#
# PermutationExplainer explainer:  15%|######9                                        | 297/2000 [01:23<07:08,  3.97it/s]
#
# PermutationExplainer explainer:  15%|#######                                        | 298/2000 [01:24<07:08,  3.98it/s]
#
# PermutationExplainer explainer:  15%|#######                                        | 299/2000 [01:24<07:05,  4.00it/s]
#
# PermutationExplainer explainer:  15%|#######                                        | 300/2000 [01:24<07:05,  4.00it/s]
#
# PermutationExplainer explainer:  15%|#######                                        | 301/2000 [01:24<07:06,  3.98it/s]
#
# PermutationExplainer explainer:  15%|#######                                        | 302/2000 [01:25<09:44,  2.91it/s]
#
# PermutationExplainer explainer:  15%|#######1                                       | 303/2000 [01:25<08:54,  3.17it/s]
#
# PermutationExplainer explainer:  15%|#######1                                       | 304/2000 [01:25<08:20,  3.39it/s]
#
# PermutationExplainer explainer:  15%|#######1                                       | 305/2000 [01:26<07:58,  3.54it/s]
#
# PermutationExplainer explainer:  15%|#######1                                       | 306/2000 [01:26<07:40,  3.68it/s]
#
# PermutationExplainer explainer:  15%|#######2                                       | 307/2000 [01:26<07:46,  3.63it/s]
#
# PermutationExplainer explainer:  15%|#######2                                       | 308/2000 [01:26<07:38,  3.69it/s]
#
# PermutationExplainer explainer:  15%|#######2                                       | 309/2000 [01:27<07:21,  3.83it/s]
#
# PermutationExplainer explainer:  16%|#######2                                       | 310/2000 [01:27<07:15,  3.88it/s]
#
# PermutationExplainer explainer:  16%|#######3                                       | 311/2000 [01:27<07:12,  3.91it/s]
#
# PermutationExplainer explainer:  16%|#######3                                       | 312/2000 [01:27<07:05,  3.96it/s]
#
# PermutationExplainer explainer:  16%|#######3                                       | 313/2000 [01:28<07:00,  4.01it/s]
#
# PermutationExplainer explainer:  16%|#######3                                       | 314/2000 [01:28<07:00,  4.01it/s]
#
# PermutationExplainer explainer:  16%|#######4                                       | 315/2000 [01:28<06:57,  4.04it/s]
#
# PermutationExplainer explainer:  16%|#######4                                       | 316/2000 [01:28<06:53,  4.08it/s]
#
# PermutationExplainer explainer:  16%|#######4                                       | 317/2000 [01:29<06:57,  4.03it/s]
#
# PermutationExplainer explainer:  16%|#######4                                       | 318/2000 [01:29<09:25,  2.97it/s]
#
# PermutationExplainer explainer:  16%|#######4                                       | 319/2000 [01:29<08:46,  3.19it/s]
#
# PermutationExplainer explainer:  16%|#######5                                       | 320/2000 [01:30<08:13,  3.40it/s]
#
# PermutationExplainer explainer:  16%|#######5                                       | 321/2000 [01:30<07:52,  3.55it/s]
#
# PermutationExplainer explainer:  16%|#######5                                       | 322/2000 [01:30<07:36,  3.67it/s]
#
# PermutationExplainer explainer:  16%|#######5                                       | 323/2000 [01:30<07:20,  3.81it/s]
#
# PermutationExplainer explainer:  16%|#######6                                       | 324/2000 [01:31<07:12,  3.88it/s]
#
# PermutationExplainer explainer:  16%|#######6                                       | 325/2000 [01:31<07:10,  3.90it/s]
#
# PermutationExplainer explainer:  16%|#######6                                       | 326/2000 [01:31<07:03,  3.95it/s]
#
# PermutationExplainer explainer:  16%|#######6                                       | 327/2000 [01:31<07:00,  3.98it/s]
#
# PermutationExplainer explainer:  16%|#######7                                       | 328/2000 [01:32<07:02,  3.96it/s]
#
# PermutationExplainer explainer:  16%|#######7                                       | 329/2000 [01:32<06:59,  3.98it/s]
#
# PermutationExplainer explainer:  16%|#######7                                       | 330/2000 [01:32<06:58,  3.99it/s]
#
# PermutationExplainer explainer:  17%|#######7                                       | 331/2000 [01:32<06:59,  3.98it/s]
#
# PermutationExplainer explainer:  17%|#######8                                       | 332/2000 [01:33<06:58,  3.99it/s]
#
# PermutationExplainer explainer:  17%|#######8                                       | 333/2000 [01:33<06:55,  4.01it/s]
#
# PermutationExplainer explainer:  17%|#######8                                       | 334/2000 [01:33<09:32,  2.91it/s]
#
# PermutationExplainer explainer:  17%|#######8                                       | 335/2000 [01:34<08:47,  3.16it/s]
#
# PermutationExplainer explainer:  17%|#######8                                       | 336/2000 [01:34<08:19,  3.33it/s]
#
# PermutationExplainer explainer:  17%|#######9                                       | 337/2000 [01:34<07:54,  3.50it/s]
#
# PermutationExplainer explainer:  17%|#######9                                       | 338/2000 [01:35<07:56,  3.48it/s]
#
# PermutationExplainer explainer:  17%|#######9                                       | 339/2000 [01:35<07:37,  3.63it/s]
#
# PermutationExplainer explainer:  17%|#######9                                       | 340/2000 [01:35<07:22,  3.75it/s]
#
# PermutationExplainer explainer:  17%|########                                       | 341/2000 [01:35<07:14,  3.82it/s]
#
# PermutationExplainer explainer:  17%|########                                       | 342/2000 [01:36<07:20,  3.76it/s]
#
# PermutationExplainer explainer:  17%|########                                       | 343/2000 [01:36<07:11,  3.84it/s]
#
# PermutationExplainer explainer:  17%|########                                       | 344/2000 [01:36<07:03,  3.91it/s]
#
# PermutationExplainer explainer:  17%|########1                                      | 345/2000 [01:36<06:59,  3.95it/s]
#
# PermutationExplainer explainer:  17%|########1                                      | 346/2000 [01:37<06:58,  3.95it/s]
#
# PermutationExplainer explainer:  17%|########1                                      | 347/2000 [01:37<06:56,  3.97it/s]
#
# PermutationExplainer explainer:  17%|########1                                      | 348/2000 [01:37<06:54,  3.99it/s]
#
# PermutationExplainer explainer:  17%|########2                                      | 349/2000 [01:37<06:51,  4.01it/s]
#
# PermutationExplainer explainer:  18%|########2                                      | 350/2000 [01:38<09:16,  2.96it/s]
#
# PermutationExplainer explainer:  18%|########2                                      | 351/2000 [01:38<08:35,  3.20it/s]
#
# PermutationExplainer explainer:  18%|########2                                      | 352/2000 [01:38<08:03,  3.41it/s]
#
# PermutationExplainer explainer:  18%|########2                                      | 353/2000 [01:39<07:44,  3.55it/s]
#
# PermutationExplainer explainer:  18%|########3                                      | 354/2000 [01:39<07:28,  3.67it/s]
#
# PermutationExplainer explainer:  18%|########3                                      | 355/2000 [01:39<07:16,  3.76it/s]
#
# PermutationExplainer explainer:  18%|########3                                      | 356/2000 [01:39<07:13,  3.79it/s]
#
# PermutationExplainer explainer:  18%|########3                                      | 357/2000 [01:40<07:05,  3.86it/s]
#
# PermutationExplainer explainer:  18%|########4                                      | 358/2000 [01:40<06:58,  3.93it/s]
#
# PermutationExplainer explainer:  18%|########4                                      | 359/2000 [01:40<06:56,  3.94it/s]
#
# PermutationExplainer explainer:  18%|########4                                      | 360/2000 [01:40<06:52,  3.98it/s]
#
# PermutationExplainer explainer:  18%|########4                                      | 361/2000 [01:41<06:50,  3.99it/s]
#
# PermutationExplainer explainer:  18%|########5                                      | 362/2000 [01:41<06:49,  4.00it/s]
#
# PermutationExplainer explainer:  18%|########5                                      | 363/2000 [01:41<06:47,  4.02it/s]
#
# PermutationExplainer explainer:  18%|########5                                      | 364/2000 [01:41<06:46,  4.02it/s]
#
# PermutationExplainer explainer:  18%|########5                                      | 365/2000 [01:42<09:12,  2.96it/s]
#
# PermutationExplainer explainer:  18%|########6                                      | 366/2000 [01:42<08:30,  3.20it/s]
#
# PermutationExplainer explainer:  18%|########6                                      | 367/2000 [01:42<07:59,  3.41it/s]
#
# PermutationExplainer explainer:  18%|########6                                      | 368/2000 [01:43<07:37,  3.57it/s]
#
# PermutationExplainer explainer:  18%|########6                                      | 369/2000 [01:43<07:43,  3.52it/s]
#
# PermutationExplainer explainer:  18%|########6                                      | 370/2000 [01:43<07:26,  3.65it/s]
#
# PermutationExplainer explainer:  19%|########7                                      | 371/2000 [01:43<07:10,  3.79it/s]
#
# PermutationExplainer explainer:  19%|########7                                      | 372/2000 [01:44<07:04,  3.83it/s]
#
# PermutationExplainer explainer:  19%|########7                                      | 373/2000 [01:44<06:57,  3.89it/s]
#
# PermutationExplainer explainer:  19%|########7                                      | 374/2000 [01:44<06:52,  3.94it/s]
#
# PermutationExplainer explainer:  19%|########8                                      | 375/2000 [01:44<06:55,  3.91it/s]
#
# PermutationExplainer explainer:  19%|########8                                      | 376/2000 [01:45<06:48,  3.97it/s]
#
# PermutationExplainer explainer:  19%|########8                                      | 377/2000 [01:45<06:47,  3.99it/s]
#
# PermutationExplainer explainer:  19%|########8                                      | 378/2000 [01:45<06:51,  3.94it/s]
#
# PermutationExplainer explainer:  19%|########9                                      | 379/2000 [01:45<06:45,  3.99it/s]
#
# PermutationExplainer explainer:  19%|########9                                      | 380/2000 [01:46<06:42,  4.02it/s]
#
# PermutationExplainer explainer:  19%|########9                                      | 381/2000 [01:46<09:10,  2.94it/s]
#
# PermutationExplainer explainer:  19%|########9                                      | 382/2000 [01:46<08:28,  3.18it/s]
#
# PermutationExplainer explainer:  19%|#########                                      | 383/2000 [01:47<08:00,  3.37it/s]
#
# PermutationExplainer explainer:  19%|#########                                      | 384/2000 [01:47<07:37,  3.54it/s]
#
# PermutationExplainer explainer:  19%|#########                                      | 385/2000 [01:47<07:20,  3.66it/s]
#
# PermutationExplainer explainer:  19%|#########                                      | 386/2000 [01:47<07:10,  3.75it/s]
#
# PermutationExplainer explainer:  19%|#########                                      | 387/2000 [01:48<07:03,  3.81it/s]
#
# PermutationExplainer explainer:  19%|#########1                                     | 388/2000 [01:48<06:57,  3.86it/s]
#
# PermutationExplainer explainer:  19%|#########1                                     | 389/2000 [01:48<06:54,  3.89it/s]
#
# ...
#
# PermutationExplainer explainer:  94%|###########################################1  | 1874/2000 [08:39<00:33,  3.75it/s]
#
# PermutationExplainer explainer:  94%|###########################################1  | 1875/2000 [08:39<00:32,  3.81it/s]
#
# PermutationExplainer explainer:  94%|###########################################1  | 1876/2000 [08:40<00:33,  3.76it/s]
#
# PermutationExplainer explainer:  94%|###########################################1  | 1877/2000 [08:40<00:32,  3.84it/s]
#
# PermutationExplainer explainer:  94%|###########################################1  | 1878/2000 [08:40<00:31,  3.89it/s]
#
# PermutationExplainer explainer:  94%|###########################################2  | 1879/2000 [08:40<00:30,  3.90it/s]
#
# PermutationExplainer explainer:  94%|###########################################2  | 1880/2000 [08:41<00:31,  3.82it/s]
#
# PermutationExplainer explainer:  94%|###########################################2  | 1881/2000 [08:41<00:30,  3.86it/s]
#
# PermutationExplainer explainer:  94%|###########################################2  | 1882/2000 [08:41<00:30,  3.91it/s]
#
# PermutationExplainer explainer:  94%|###########################################3  | 1883/2000 [08:41<00:29,  3.98it/s]
#
# PermutationExplainer explainer:  94%|###########################################3  | 1884/2000 [08:42<00:46,  2.52it/s]
#
# PermutationExplainer explainer:  94%|###########################################3  | 1885/2000 [08:42<00:40,  2.83it/s]
#
# PermutationExplainer explainer:  94%|###########################################3  | 1886/2000 [08:43<00:36,  3.12it/s]
#
# PermutationExplainer explainer:  94%|###########################################4  | 1887/2000 [08:43<00:33,  3.38it/s]
#
# PermutationExplainer explainer:  94%|###########################################4  | 1888/2000 [08:43<00:32,  3.47it/s]
#
# PermutationExplainer explainer:  94%|###########################################4  | 1889/2000 [08:43<00:30,  3.63it/s]
#
# PermutationExplainer explainer:  94%|###########################################4  | 1890/2000 [08:44<00:29,  3.76it/s]
#
# PermutationExplainer explainer:  95%|###########################################4  | 1891/2000 [08:44<00:28,  3.82it/s]
#
# PermutationExplainer explainer:  95%|###########################################5  | 1892/2000 [08:44<00:28,  3.79it/s]
#
# PermutationExplainer explainer:  95%|###########################################5  | 1893/2000 [08:44<00:27,  3.84it/s]
#
# PermutationExplainer explainer:  95%|###########################################5  | 1894/2000 [08:45<00:27,  3.90it/s]
#
# PermutationExplainer explainer:  95%|###########################################5  | 1895/2000 [08:45<00:26,  3.90it/s]
#
# PermutationExplainer explainer:  95%|###########################################6  | 1896/2000 [08:45<00:27,  3.84it/s]
#
# PermutationExplainer explainer:  95%|###########################################6  | 1897/2000 [08:46<00:26,  3.87it/s]
#
# PermutationExplainer explainer:  95%|###########################################6  | 1898/2000 [08:46<00:26,  3.92it/s]
#
# PermutationExplainer explainer:  95%|###########################################6  | 1899/2000 [08:46<00:25,  3.91it/s]
#
# PermutationExplainer explainer:  95%|###########################################6  | 1900/2000 [08:46<00:26,  3.81it/s]
#
# PermutationExplainer explainer:  95%|###########################################7  | 1901/2000 [08:47<00:25,  3.85it/s]
#
# PermutationExplainer explainer:  95%|###########################################7  | 1902/2000 [08:47<00:25,  3.92it/s]
#
# PermutationExplainer explainer:  95%|###########################################7  | 1903/2000 [08:47<00:24,  3.92it/s]
#
# PermutationExplainer explainer:  95%|###########################################7  | 1904/2000 [08:47<00:24,  3.85it/s]
#
# PermutationExplainer explainer:  95%|###########################################8  | 1905/2000 [08:48<00:24,  3.88it/s]
#
# PermutationExplainer explainer:  95%|###########################################8  | 1906/2000 [08:48<00:23,  3.92it/s]
#
# PermutationExplainer explainer:  95%|###########################################8  | 1907/2000 [08:48<00:23,  3.94it/s]
#
# PermutationExplainer explainer:  95%|###########################################8  | 1908/2000 [08:49<00:37,  2.48it/s]
#
# PermutationExplainer explainer:  95%|###########################################9  | 1909/2000 [08:49<00:32,  2.80it/s]
#
# PermutationExplainer explainer:  96%|###########################################9  | 1910/2000 [08:49<00:29,  3.08it/s]
#
# PermutationExplainer explainer:  96%|###########################################9  | 1911/2000 [08:50<00:26,  3.31it/s]
#
# PermutationExplainer explainer:  96%|###########################################9  | 1912/2000 [08:50<00:25,  3.44it/s]
#
# PermutationExplainer explainer:  96%|###########################################9  | 1913/2000 [08:50<00:24,  3.49it/s]
#
# PermutationExplainer explainer:  96%|############################################  | 1914/2000 [08:50<00:23,  3.60it/s]
#
# PermutationExplainer explainer:  96%|############################################  | 1915/2000 [08:51<00:23,  3.67it/s]
#
# PermutationExplainer explainer:  96%|############################################  | 1916/2000 [08:51<00:23,  3.63it/s]
#
# PermutationExplainer explainer:  96%|############################################  | 1917/2000 [08:51<00:22,  3.72it/s]
#
# PermutationExplainer explainer:  96%|############################################1 | 1918/2000 [08:51<00:21,  3.77it/s]
#
# PermutationExplainer explainer:  96%|############################################1 | 1919/2000 [08:52<00:21,  3.81it/s]
#
# PermutationExplainer explainer:  96%|############################################1 | 1920/2000 [08:52<00:21,  3.73it/s]
#
# PermutationExplainer explainer:  96%|############################################1 | 1921/2000 [08:52<00:21,  3.76it/s]
#
# PermutationExplainer explainer:  96%|############################################2 | 1922/2000 [08:52<00:20,  3.82it/s]
#
# PermutationExplainer explainer:  96%|############################################2 | 1923/2000 [08:53<00:19,  3.85it/s]
#
# PermutationExplainer explainer:  96%|############################################2 | 1924/2000 [08:53<00:20,  3.74it/s]
#
# PermutationExplainer explainer:  96%|############################################2 | 1925/2000 [08:53<00:19,  3.80it/s]
#
# PermutationExplainer explainer:  96%|############################################2 | 1926/2000 [08:54<00:19,  3.87it/s]
#
# PermutationExplainer explainer:  96%|############################################3 | 1927/2000 [08:54<00:18,  3.89it/s]
#
# PermutationExplainer explainer:  96%|############################################3 | 1928/2000 [08:54<00:18,  3.80it/s]
#
# PermutationExplainer explainer:  96%|############################################3 | 1929/2000 [08:54<00:18,  3.82it/s]
#
# PermutationExplainer explainer:  96%|############################################3 | 1930/2000 [08:55<00:18,  3.88it/s]
#
# PermutationExplainer explainer:  97%|############################################4 | 1931/2000 [08:55<00:17,  3.94it/s]
#
# PermutationExplainer explainer:  97%|############################################4 | 1932/2000 [08:56<00:27,  2.49it/s]
#
# PermutationExplainer explainer:  97%|############################################4 | 1933/2000 [08:56<00:23,  2.81it/s]
#
# PermutationExplainer explainer:  97%|############################################4 | 1934/2000 [08:56<00:21,  3.01it/s]
#
# PermutationExplainer explainer:  97%|############################################5 | 1935/2000 [08:56<00:20,  3.21it/s]
#
# PermutationExplainer explainer:  97%|############################################5 | 1936/2000 [08:57<00:19,  3.29it/s]
#
# PermutationExplainer explainer:  97%|############################################5 | 1937/2000 [08:57<00:18,  3.45it/s]
#
# PermutationExplainer explainer:  97%|############################################5 | 1938/2000 [08:57<00:17,  3.60it/s]
#
# PermutationExplainer explainer:  97%|############################################5 | 1939/2000 [08:57<00:16,  3.71it/s]
#
# PermutationExplainer explainer:  97%|############################################6 | 1940/2000 [08:58<00:16,  3.62it/s]
#
# PermutationExplainer explainer:  97%|############################################6 | 1941/2000 [08:58<00:15,  3.71it/s]
#
# PermutationExplainer explainer:  97%|############################################6 | 1942/2000 [08:58<00:15,  3.73it/s]
#
# PermutationExplainer explainer:  97%|############################################6 | 1943/2000 [08:58<00:15,  3.79it/s]
#
# PermutationExplainer explainer:  97%|############################################7 | 1944/2000 [08:59<00:14,  3.74it/s]
#
# PermutationExplainer explainer:  97%|############################################7 | 1945/2000 [08:59<00:14,  3.80it/s]
#
# PermutationExplainer explainer:  97%|############################################7 | 1946/2000 [08:59<00:13,  3.86it/s]
#
# PermutationExplainer explainer:  97%|############################################7 | 1947/2000 [08:59<00:13,  3.88it/s]
#
# PermutationExplainer explainer:  97%|############################################8 | 1948/2000 [09:00<00:13,  3.82it/s]
#
# PermutationExplainer explainer:  97%|############################################8 | 1949/2000 [09:00<00:13,  3.87it/s]
#
# PermutationExplainer explainer:  98%|############################################8 | 1950/2000 [09:00<00:12,  3.91it/s]
#
# PermutationExplainer explainer:  98%|############################################8 | 1951/2000 [09:01<00:12,  3.94it/s]
#
# PermutationExplainer explainer:  98%|############################################8 | 1952/2000 [09:01<00:12,  3.84it/s]
#
# PermutationExplainer explainer:  98%|############################################9 | 1953/2000 [09:01<00:12,  3.85it/s]
#
# PermutationExplainer explainer:  98%|############################################9 | 1954/2000 [09:01<00:11,  3.88it/s]
#
# PermutationExplainer explainer:  98%|############################################9 | 1955/2000 [09:02<00:11,  3.94it/s]
#
# PermutationExplainer explainer:  98%|############################################9 | 1956/2000 [09:02<00:17,  2.45it/s]
#
# PermutationExplainer explainer:  98%|############################################# | 1957/2000 [09:03<00:15,  2.77it/s]
#
# PermutationExplainer explainer:  98%|############################################# | 1958/2000 [09:03<00:13,  3.04it/s]
#
# PermutationExplainer explainer:  98%|############################################# | 1959/2000 [09:03<00:12,  3.27it/s]
#
# PermutationExplainer explainer:  98%|############################################# | 1960/2000 [09:03<00:12,  3.33it/s]
#
# PermutationExplainer explainer:  98%|#############################################1| 1961/2000 [09:04<00:11,  3.49it/s]
#
# PermutationExplainer explainer:  98%|#############################################1| 1962/2000 [09:04<00:10,  3.64it/s]
#
# PermutationExplainer explainer:  98%|#############################################1| 1963/2000 [09:04<00:09,  3.74it/s]
#
# PermutationExplainer explainer:  98%|#############################################1| 1964/2000 [09:04<00:09,  3.72it/s]
#
# PermutationExplainer explainer:  98%|#############################################1| 1965/2000 [09:05<00:09,  3.80it/s]
#
# PermutationExplainer explainer:  98%|#############################################2| 1966/2000 [09:05<00:08,  3.87it/s]
#
# PermutationExplainer explainer:  98%|#############################################2| 1967/2000 [09:05<00:08,  3.92it/s]
#
# PermutationExplainer explainer:  98%|#############################################2| 1968/2000 [09:05<00:08,  3.83it/s]
#
# PermutationExplainer explainer:  98%|#############################################2| 1969/2000 [09:06<00:08,  3.84it/s]
#
# PermutationExplainer explainer:  98%|#############################################3| 1970/2000 [09:06<00:07,  3.86it/s]
#
# PermutationExplainer explainer:  99%|#############################################3| 1971/2000 [09:06<00:07,  3.88it/s]
#
# PermutationExplainer explainer:  99%|#############################################3| 1972/2000 [09:06<00:07,  3.82it/s]
#
# PermutationExplainer explainer:  99%|#############################################3| 1973/2000 [09:07<00:07,  3.84it/s]
#
# PermutationExplainer explainer:  99%|#############################################4| 1974/2000 [09:07<00:06,  3.86it/s]
#
# PermutationExplainer explainer:  99%|#############################################4| 1975/2000 [09:07<00:06,  3.88it/s]
#
# PermutationExplainer explainer:  99%|#############################################4| 1976/2000 [09:07<00:06,  3.81it/s]
#
# PermutationExplainer explainer:  99%|#############################################4| 1977/2000 [09:08<00:05,  3.87it/s]
#
# PermutationExplainer explainer:  99%|#############################################4| 1978/2000 [09:08<00:05,  3.88it/s]
#
# PermutationExplainer explainer:  99%|#############################################5| 1979/2000 [09:08<00:05,  3.80it/s]
#
# PermutationExplainer explainer:  99%|#############################################5| 1980/2000 [09:09<00:08,  2.47it/s]
#
# PermutationExplainer explainer:  99%|#############################################5| 1981/2000 [09:09<00:06,  2.79it/s]
#
# PermutationExplainer explainer:  99%|#############################################5| 1982/2000 [09:09<00:05,  3.05it/s]
#
# PermutationExplainer explainer:  99%|#############################################6| 1983/2000 [09:10<00:05,  3.22it/s]
#
# PermutationExplainer explainer:  99%|#############################################6| 1984/2000 [09:10<00:04,  3.39it/s]
#
# PermutationExplainer explainer:  99%|#############################################6| 1985/2000 [09:10<00:04,  3.53it/s]
#
# PermutationExplainer explainer:  99%|#############################################6| 1986/2000 [09:11<00:03,  3.54it/s]
#
# PermutationExplainer explainer:  99%|#############################################7| 1987/2000 [09:11<00:03,  3.65it/s]
#
# PermutationExplainer explainer:  99%|#############################################7| 1988/2000 [09:11<00:03,  3.73it/s]
#
# PermutationExplainer explainer:  99%|#############################################7| 1989/2000 [09:11<00:02,  3.78it/s]
#
# PermutationExplainer explainer: 100%|#############################################7| 1990/2000 [09:12<00:02,  3.67it/s]
#
# PermutationExplainer explainer: 100%|#############################################7| 1991/2000 [09:12<00:02,  3.73it/s]
#
# PermutationExplainer explainer: 100%|#############################################8| 1992/2000 [09:12<00:02,  3.79it/s]
#
# PermutationExplainer explainer: 100%|#############################################8| 1993/2000 [09:12<00:01,  3.77it/s]
#
# PermutationExplainer explainer: 100%|#############################################8| 1994/2000 [09:13<00:01,  3.84it/s]
#
# PermutationExplainer explainer: 100%|#############################################8| 1995/2000 [09:13<00:01,  3.87it/s]
#
# PermutationExplainer explainer: 100%|#############################################9| 1996/2000 [09:13<00:01,  3.84it/s]
#
# PermutationExplainer explainer: 100%|#############################################9| 1997/2000 [09:13<00:00,  3.79it/s]
#
# PermutationExplainer explainer: 100%|#############################################9| 1998/2000 [09:14<00:00,  3.82it/s]
#
# PermutationExplainer explainer: 100%|#############################################9| 1999/2000 [09:14<00:00,  3.90it/s]
#
# PermutationExplainer explainer: 100%|##############################################| 2000/2000 [09:14<00:00,  3.91it/s]
#
# PermutationExplainer explainer: 2001it [09:14,  3.85it/s]
#
# PermutationExplainer explainer: 2001it [09:14,  3.54it/s]
# 100%|███████████████████████████████████████████████| 2/2 [49:23<00:00, 1481.76s/trial, best loss: -0.6667735404038576]
# Melhores hiperparâmetros: {'colsample_bytree': 0.65, 'gamma': 0.9500000000000001, 'learning_rate': 0.32255069033505585, 'max_depth': 7, 'min_child_weight': 4.0, 'objective': 'binary:logistic', 'reg_alpha': 0.2732811970249517, 'reg_lambda': 0.04756742844631273, 'seed': 123, 'subsample': 0.9}

# %%
best_hyperparams = space_eval(space, best_hyperparams)
best_hyperparams
# Out:
# {'colsample_bytree': 0.65,
#  'gamma': 0.9500000000000001,
#  'learning_rate': 0.32255069033505585,
#  'max_depth': 7,
#  'min_child_weight': 4.0,
#  'objective': 'binary:logistic',
#  'reg_alpha': 0.2732811970249517,
#  'reg_lambda': 0.04756742844631273,
#  'seed': 123,
#  'subsample': 0.9}

# %% [markdown]
# ### Treinamento do Modelo XGBoost com melhores parametros

# %%
# Iniciar rastreamento MLflow
with mlflow.start_run(experiment_id=experiment_id, run_name='Treinamento do melhor modelo modelo XGBoost', nested=True, #run_id = 'b146f1b10b7c4d1b94ec262f6dffb274',
                     description = 'Treinando o XGBoost com os melhores parametros',
                     tags = {"Versão do modelo": "1", "Algoritmo": "Xgboost"}):
    mlflow.log_params(best_hyperparams)

    # Treinamento do Modelo XGBoost com melhores parâmetros
    model = xgb.XGBClassifier(max_depth = space['max_depth'],
                                  learning_rate = space['learning_rate'],
                                  reg_alpha = space['reg_alpha'],
                                  reg_lambda = space['reg_lambda'],
                                  min_child_weight = space['min_child_weight'],
                                  subsample = space['subsample'],
                                  colsample_bytree = space['colsample_bytree'],
                                  gamma = space['gamma'],
                                  objective = space['objective'],
                                  seed = space['seed'])

    # Treino do modelo utilizando dados do SMOTE 
    model.fit(X_smote_a, y_smote_a)

    # Logar o modelo
    mlflow.xgboost.log_model(model, "model")

    # Teste do modelo
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1]

    # Teste do modelo e log das curvas
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)
    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)

    # Plotar e salvar a Curva de Precisão-Recall
    plt.figure(figsize=(8, 6))
    plt.plot(recall, precision, marker='.')
    plt.title('Curva de Precisão-Recall')
    plt.xlabel('Recall')
    plt.ylabel('Precisão')
    plt.savefig('precision_recall_curve.png')
    plt.close()

    # Plotar e salvar a Curva ROC
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, linestyle='--')
    plt.title('Curva ROC')
    plt.xlabel('Taxa de Falso Positivo')
    plt.ylabel('Taxa de Verdadeiro Positivo')
    plt.savefig('roc_curve.png')
    plt.close()

    # Logar gráficos como artefatos
    mlflow.log_artifact('precision_recall_curve.png')
    mlflow.log_artifact('roc_curve.png')

    # Create a model signature
    signature = infer_signature(X_test, model.predict(X_test))
    mlflow.xgboost.log_model(model, "model_xgb", signature=signature)
    model_uri = mlflow.get_artifact_uri("model_xgb")
    
    eval_data = pd.DataFrame(X_test, columns=dt_ax.columns)
    eval_data['atraso30_m3'] = y_test.reset_index(drop=True)

    # Evaluate the logged model
    result = mlflow.evaluate(
        model_uri,
        eval_data,
        targets="atraso30_m3",
        model_type="classifier",
        evaluators=["default"])
# Out:
# 2024/05/01 13:07:04 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under gs://mlflow-bucket-teste/mlruns/1/34529768635140ad9e9dc8b0d619cc59/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2024/05/01 13:10:08 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed. The model artifacts have been logged successfully under gs://mlflow-bucket-teste/mlruns/1/34529768635140ad9e9dc8b0d619cc59/artifacts. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# Downloading artifacts:   0%|          | 0/9 [00:00<?, ?it/s]
# 2024/05/01 13:10:37 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
# 2024/05/01 13:10:37 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
# 2024/05/01 13:10:37 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as binary dataset, positive label is 1, negative label is 0.
# 2024/05/01 13:10:38 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
# 2024/05/01 13:10:41 INFO mlflow.models.evaluation.default_evaluator: Shap explainer PermutationExplainer is used.
# PermutationExplainer explainer: 2001it [08:56,  3.65it/s]

# %% [markdown]
# ## Statsmodels
#
# Obs.: O resultado do modelo abaixo não ficou bom. O objetivo aqui é utilizar o statmodels como exemplo prático em cima de um conjuto de dados.

# %%
with mlflow.start_run(experiment_id=experiment_id, run_name='Treinamento de regressão com Statsmodels', nested=True, #run_id = '496bc7ea97784b01bacdf67f57df5cb0', 
                     description = 'Teste implementando statmodels no mlflow',
                     tags = {"teste_statmodels": "deploy statmodel moflow", "objetivo": "testar biblioteca statmodels+mlfow", "Versão do teste": "1.0"}):
    mlflow.statsmodels.autolog()
    
    if 'const' not in X_smote_a.columns:
        X_train = sm.add_constant(X_smote_a, has_constant='add')
    else:
        X_train = X_smote_a

    if 'const' not in X_test.columns:
        X_test = sm.add_constant(X_test, has_constant='add')
    else:
        X_test = X_test

    # Criar e ajustar o modelo
    model = sm.Logit(y_smote_a, X_train)
    result = model.fit(method='bfgs')

    cleaned_params = {clean_param_name(k): v for k, v in dict(result.params).items()}
    mlflow.log_params(cleaned_params)

    # Fazer previsões
    y_pred_proba = result.predict(X_test)
    y_pred = (y_pred_proba > 0.5).astype(int)

    # Teste do modelo e log das curvas
    precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)
    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    roc_auc = auc(fpr, tpr)

    # Avaliar e logar métricas
    roc_auc = roc_auc_score(y_test, y_pred_proba)
    accuracy = accuracy_score(y_test, y_pred)
    mlflow.log_metric("AUC ROC", roc_auc)
    mlflow.log_metric("Accuracy", accuracy)

    # Matriz de Confusão
    conf_matrix = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(6, 4))
    sns.heatmap(conf_matrix, annot=True, fmt='d')
    plt.title('Matriz de Confusão')
    conf_matrix_path = 'confusion_matrix.png'
    plt.savefig(conf_matrix_path)
    plt.close()
    mlflow.log_artifact(conf_matrix_path)

    # Coeficientes do Modelo
    plt.figure(figsize=(8, 6))
    result.params[1:].sort_values().plot(kind='bar')
    plt.title('Coeficientes do Modelo de Regressão Logística')
    coefficients_path = 'model_coefficients.png'
    plt.savefig(coefficients_path)
    plt.close()
    mlflow.log_artifact(coefficients_path)

    # Logar gráficos de desempenho do modelo
    plt.figure(figsize=(8, 6))
    precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)
    plt.plot(recall, precision, marker='.')
    plt.title('Curva de Precisão-Recall')
    plt.xlabel('Recall')
    plt.ylabel('Precisão')
    pr_curve_path = 'precision_recall_curve.png'
    plt.savefig(pr_curve_path)
    plt.close()
    mlflow.log_artifact(pr_curve_path)

    plt.figure(figsize=(8, 6))
    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    plt.plot(fpr, tpr, linestyle='--')
    plt.title('Curva ROC')
    plt.xlabel('Taxa de Falso Positivo')
    plt.ylabel('Taxa de Verdadeiro Positivo')
    roc_curve_path = 'roc_curve.png'
    plt.savefig(roc_curve_path)
    plt.close()
    mlflow.log_artifact(roc_curve_path)

    # Logando o modelo
    mlflow.statsmodels.log_model(result, "model_statsmodels")

    report_dict = classification_report(y_test, y_pred, output_dict=True)
    # Logar métricas detalhadas no MLflow
    for label, metrics in report_dict.items():
        if label not in ["accuracy", "macro avg", "weighted avg"]:  # Ignorando a média total por enquanto
            mlflow.log_metric(f"Precision Classe {label}", metrics['precision'])
            mlflow.log_metric(f"Recall Classe {label}", metrics['recall'])
            mlflow.log_metric(f"F1-score Classe {label}", metrics['f1-score'])
            mlflow.log_metric(f"Support Classe {label}", metrics['support'])

    # Métricas globais
    mlflow.log_metric("Accuracy Total", report_dict['accuracy'])
    mlflow.log_metric("Macro Avg Precision", report_dict['macro avg']['precision'])
    mlflow.log_metric("Macro Avg Recall", report_dict['macro avg']['recall'])
    mlflow.log_metric("Macro Avg F1-score", report_dict['macro avg']['f1-score'])
    mlflow.log_metric("Weighted Avg Precision", report_dict['weighted avg']['precision'])
    mlflow.log_metric("Weighted Avg Recall", report_dict['weighted avg']['recall'])
    mlflow.log_metric("Weighted Avg F1-score", report_dict['weighted avg']['f1-score'])

    # Exibir resultados adicionais
    print("AUC-ROC:", roc_auc)
    print("Acurácia:", accuracy)
    print(classification_report(y_test, y_pred))
    
    # Avaliação com MLflow (Opcional se MLflow suporta evaluate para statsmodels)
    eval_data = pd.DataFrame(X_test)
    eval_data['real'] = y_test.reset_index(drop=True)
    model_uri = mlflow.get_artifact_uri("model_statsmodels")
# Out:
#          Current function value: 0.649085
#          Iterations: 35
#          Function evaluations: 36
#          Gradient evaluations: 36
# 2024/05/01 13:21:09 WARNING mlflow.statsmodels: The fitted model is larger than 100 MB, saving it as artifacts is time consuming.
# To reduce model size, use `mlflow.statsmodels.autolog(log_models=False)` and manually log model by `mlflow.statsmodels.log_model(model, remove_data=True, artifact_path="model")`
# AUC-ROC: 0.6367040967191571
# Acurácia: 0.5986705328810592
#               precision    recall  f1-score   support
#
#            0       0.19      0.59      0.28      4979
#            1       0.90      0.60      0.72     31577
#
#     accuracy                           0.60     36556
#    macro avg       0.55      0.59      0.50     36556
# weighted avg       0.80      0.60      0.66     36556

# %%
mlflow.end_run()
